# %%
source("../2.Fire_Seasson/Funciones_FS.r")

# %% [markdown]
# ## Grid 0.5

# %%
grid_05 = get(load("../1.Upscaling/upscaling_ba/ba_grid_05.Rdata"))
#grid_fba = get(load("../1.Upscaling/upscaling_fba/ fba_grid_5.Rdata"))
df_grid = get(load("../3.Datos generados/dataframes/df_grid_05.Rdata"))

# %%
df_grid_conFs <- df_grid[df_grid$FsOrNot != 0,]
df_grid_Length1 <- df_grid_conFs[df_grid_conFs$Length == 1,]
dfPhase <- data.frame('FS'=df_grid_Length1$MainStart,'P'= df_grid_Length1$P)
#dfPhase

vector_minimos <- c()
vector_maximos <- c()
vector_means <- c()
vector_medianas <- c()
for (i in 1:12){
    vector_minimos <- c(vector_minimos,round( min(dfPhase[dfPhase$FS==i,]$P),digits = 3))
    vector_maximos <- c(vector_maximos,round(max(dfPhase[dfPhase$FS==i,]$P),digits = 3))
    vector_means <- c(vector_means, round(mean(dfPhase[dfPhase$FS==i,]$P),digits = 3))
    vector_medianas <- c(vector_medianas, round(median(dfPhase[dfPhase$FS==i,]$P),digits = 3))
}
dfPhase.st <- data.frame('meses' = seq(1,12),vector_minimos,vector_maximos,vector_means,vector_medianas)
dfPhase.st
# Out:
#    meses vector_minimos vector_maximos vector_means vector_medianas
# 1   1    -1.570          1.571          0.943        1.306
# 2   2    -1.566          1.544          0.732        0.773
# 3   3    -1.563          1.380          0.217        0.214
# 4   4    -1.415          1.549         -0.287       -0.318
# 5   5    -1.562          1.570         -0.740       -0.781
# 6   6    -1.571          1.571         -0.807       -1.239
# 7   7    -1.571          1.566          0.616        1.117
# 8   8    -1.034          1.047          0.887        1.025
# 9   9    -0.466          0.524          0.344        0.464
# 10 10    -0.895          0.000         -0.166       -0.062
# 11 11    -1.045         -0.524         -0.636       -0.524
# 12 12    -1.047         -1.047         -1.047       -1.047

# %%
SeassonalTiming_viz <- quantity2clim(quantity = df_grid$'P', what = 'Phase', ref.grid = grid_05, backperm = NULL)
spatialPlot(SeassonalTiming_viz, backdrop.theme = 'coastline')
# Out:
# plot without title

# %% [markdown]
# ## Grid 5

# %%
grid_ref = get(load("../1.Upscaling/upscaling_ba/ba_grid_05.Rdata"))
#grid_fba = get(load("../1.Upscaling/upscaling_fba/ fba_grid_5.Rdata"))
df_grid = get(load("../3.Datos generados/dataframes/df_grid_05.Rdata"))

# %%
df_grid_conFs <- df_grid[df_grid$FsOrNot != 0,]
df_grid_Length1 <- df_grid_conFs[df_grid_conFs$Length == 1,]
dfPhase <- data.frame('FS'=df_grid_Length1$MainStart,'P'= df_grid_Length1$P)

vector_minimos <- c()
vector_maximos <- c()
vector_means <- c()
vector_medianas <- c()
for (i in 1:12){
    vector_minimos <- c(vector_minimos,round( min(dfPhase[dfPhase$FS==i,]$P),digits = 3))
    vector_maximos <- c(vector_maximos,round(max(dfPhase[dfPhase$FS==i,]$P),digits = 3))
    vector_means <- c(vector_means, round(mean(dfPhase[dfPhase$FS==i,]$P),digits = 3))
    vector_medianas <- c(vector_medianas, round(median(dfPhase[dfPhase$FS==i,]$P),digits = 3))
}
dfPhase.st <- data.frame('meses' = seq(1,12),vector_minimos,vector_maximos,vector_means,vector_medianas)
dfPhase.st
# Out:
#    meses vector_minimos vector_maximos vector_means vector_medianas
# 1   1    -1.570          1.571          0.943        1.306
# 2   2    -1.566          1.544          0.732        0.773
# 3   3    -1.563          1.380          0.217        0.214
# 4   4    -1.415          1.549         -0.287       -0.318
# 5   5    -1.562          1.570         -0.740       -0.781
# 6   6    -1.571          1.571         -0.807       -1.239
# 7   7    -1.571          1.566          0.616        1.117
# 8   8    -1.034          1.047          0.887        1.025
# 9   9    -0.466          0.524          0.344        0.464
# 10 10    -0.895          0.000         -0.166       -0.062
# 11 11    -1.045         -0.524         -0.636       -0.524
# 12 12    -1.047         -1.047         -1.047       -1.047

# %%
df_grid$C[df_grid$FsOrNot == 0] <- NA
df_grid$P[df_grid$FsOrNot == 0] <- NA

# %%
df_grid<- df_grid[order(df_grid$X),]

# %%
SeassonalTiming_viz <- quantity2clim(quantity = abs(df_grid$'P'), what = 'Phase', ref.grid = grid_ref, backperm = NULL)
fig_SeassonalTiming_viz <- spatialPlot(SeassonalTiming_viz, backdrop.theme = 'coastline')
fig_SeassonalTiming_viz

plotname <- "phase_ejemplo.pdf"
pdf(plotname)
fig_SeassonalTiming_viz
dev.off()
# Out:
# png
#   2
# plot without title

# %%
SeassonalTiming_viz <- quantity2clim(quantity = abs(df_grid$'P'), what = 'Phase', ref.grid = grid_ref, backperm = NULL)
fig_SeassonalTiming_viz <- spatialPlot(SeassonalTiming_viz, backdrop.theme = 'coastline')
fig_SeassonalTiming_viz

plotname <- "phase_ejemplo2.pdf"
pdf(plotname)
fig_SeassonalTiming_viz
dev.off()
# Out:
# png
#   2
# plot without title

# %%
SeassonalConcentrationViz <- quantity2clim(quantity = df_grid$'C', what = 'Phase', ref.grid = grid_ref, backperm = NULL)

fig_SeassonalConcentrationViz <- spatialPlot(SeassonalConcentrationViz, backdrop.theme = 'coastline')
fig_SeassonalConcentrationViz
# Out:
# plot without title

# %%
plotname <- "concentracion_ejemplo.pdf"
pdf(plotname)
fig_SeassonalConcentrationViz
dev.off()
# Out:
# png
#   2
