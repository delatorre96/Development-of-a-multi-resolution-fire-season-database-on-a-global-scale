# %%
library(ggplot2)
library(ggridges)
theme_set(theme_minimal())
library('transformeR')
# Out:
#     _______   ____  ___________________  __  ________
#    / ___/ /  / /  |/  / __  /_  __/ __/ / / / / __  /
#   / /  / /  / / /|_/ / /_/ / / / / __/ / /_/ / /_/_/
#  / /__/ /__/ / /  / / __  / / / / /__ /___  / / \ \
#  \___/____/_/_/  /_/_/ /_/ /_/  \___/    /_/\/   \_\
#
#       github.com/SantanderMetGroup/climate4R
# transformeR version 2.1.3 (2021-08-04) is loaded
#
# WARNING: Your current version of transformeR (v2.1.3) is not up-to-date
#
# Get the latest stable version (2.1.5) using <devtools::install_github('SantanderMetGroup/transformeR')>
#
# Please see 'citation("transformeR")' to cite this package.

# %%
load('../1.Upscaling/upscaling_ba/ba_grid_5.Rdata',verbose = TRUE)
# Out:
# Loading objects:
#   ba.mergeGrid5

# %%
load('../3.Datos generados/dataframes/df.series_grid_5.Rdata',verbose = TRUE)
# Out:
# Loading objects:
#   df.seriesTemporales_conCoords

# %%
load('../3.Datos generados/dataframes/df_grid_5.Rdata',verbose = TRUE)
df.fireSeasson = df
# Out:
# Loading objects:
#   df

# %%
df_sinCeros <- data.frame()
for (i in 1:nrow(df.seriesTemporales_conCoords)){
    if (all(unlist(df.seriesTemporales_conCoords[i,3:14]) != 0)){
        df_sinCeros <- rbind(df_sinCeros, df.seriesTemporales_conCoords[i,])
    }
}

# %%
df_sinCeros[1:10,]
# Out:
#             coord_x coord_y X1         X2        X3        X4
# -157.5_17.5 -157.5  17.5      8.537555 167.94650 102.23748    0.9757182
# -157.5_22.5 -157.5  22.5     26.344468  62.69385 115.79825  125.6240955
# -122.5_37.5 -122.5  37.5    618.755855  84.25837  69.27618 1708.4877364
# -122.5_42.5 -122.5  42.5    531.036173 458.50596 730.13060 1335.3700182
# -122.5_47.5 -122.5  47.5     84.643805  10.00114  17.80690  160.9939682
# -122.5_57.5 -122.5  57.5    430.049077 209.53608  36.30921 1404.7980227
# -117.5_32.5 -117.5  32.5    784.874832 757.86811  98.79175  463.0558955
# -117.5_37.5 -117.5  37.5    360.734723  88.62161  21.95371  212.9511318
# -117.5_42.5 -117.5  42.5     57.323609 161.31846 209.69908  700.5233545
# -117.5_47.5 -117.5  47.5    318.020668 136.78477 814.04908 3035.7285227
#             X5         X6          X7         X8         X9         X10
# -157.5_17.5   70.78624    61.07549   330.5478  1047.7494   104.8866   112.5342
# -157.5_22.5   71.29733   282.15175   590.1779   619.0135   560.5821   217.3675
# -122.5_37.5 2745.30994  7410.61160 17981.7212 43957.0369 32520.1744 26812.8418
# -122.5_42.5 1616.43042  3304.28220 30074.5662 80886.9974 67942.6008 16887.2475
# -122.5_47.5  547.53017  2987.60453 20544.7520 24790.5938 18111.7381  7964.0189
# -122.5_57.5 4427.69585  2097.22947  6374.0469  5278.6166  2328.7774  1000.3904
# -117.5_32.5 5358.17522 11687.73178 14264.1308 15533.4921 17928.2848 18744.1274
# -117.5_37.5 1242.46736  6576.96429 17870.9162 17901.2466 18313.6895 11104.2118
# -117.5_42.5 1302.05933  3694.53478 98225.0731 97910.8756 31640.9558 12849.3690
# -117.5_47.5 3136.12495  2999.99029 29972.3783 62075.6200 60178.6231 32300.8629
#             X11         X12
# -157.5_17.5    19.34492   63.88650
# -157.5_22.5    84.84128   59.01965
# -122.5_37.5 20958.38060 2080.40000
# -122.5_42.5  5730.85188  901.86831
# -122.5_47.5  4827.75458  250.94613
# -122.5_57.5   565.77883  175.04898
# -117.5_32.5 15342.80331 5922.85934
# -117.5_37.5  2670.78609  364.68725
# -117.5_42.5  1462.27086   50.11785
# -117.5_47.5 15342.69477  463.85483

# %%
x = df_sinCeros$'coord_x'[3]
y = df_sinCeros$'coord_y'[3]
df2 <- data.frame()
for (year in 2001:2022){
    for (season in 1:12){
        subgrid <- subsetGrid(grid = ba.mergeGrid5, year = year, season = season, lonLim  = x, latLim  = y)
        df2 <- rbind(df2, c(year, season, subgrid$Data))
    }        
}
colnames(df2) = c('Year', 'Month','Burned_area')
df2$Year <- as.character(df2$Year)
for (row in 1:nrow(df2)){
    if (df2$Burned_area[row] != 0){
        df2$Burned_area[row] = df2$Month[row]
    }
}

startFireSeasson = df.fireSeasson[df.fireSeasson$coord_x == x & df.fireSeasson$coord_y == y, ]$main_fire_season_start
endFireSeasson = df.fireSeasson[df.fireSeasson$coord_x == x & df.fireSeasson$coord_y == y, ]$main_fire_season_end
ggplot(df2, aes(x = Burned_area, y = Year, fill = stat(x))) +
  geom_density_ridges_gradient(scale = 2, rel_min_height = 0.01, gradient_lwd = 1.)+
  scale_fill_viridis_c(name = "Meses Fire Seasson", option = "C") +
  labs(
    title = 'Fire Seasson años 2001-2022 en un pixel',
    subtitle = paste0('Coordenadas ','lon = ',x,' lat = ',y)
  ) +
  theme_ridges(font_size = 13, grid = TRUE) + 
  theme(axis.title.y = element_blank()) +
  geom_vline(xintercept = c(startFireSeasson, endFireSeasson), color = "red", linetype = "dashed")
ggsave(paste0('FireSeasson',x,'_',y,'.png'))

df.fireSeasson[df.fireSeasson$coord_x == x & df.fireSeasson$coord_y == y, ]
# Out:
# Picking joint bandwidth of 2.27
#
# Saving 6.67 x 6.67 in image
#
# Picking joint bandwidth of 2.27
#     coord_x coord_y FireSeassonOrNot main_fire_season_start
# 422 -122.5  37.5    1                1
#     main_fire_season_end secondary_fire_season_start secondary_fire_season_end
# 422 9                    NA                          NA
#     fireSeassonLength SeassonalConcentration SeassonalTiming FBA
# 422 9                 0.7063497              0.6500246       0.4750457
# plot without title

# %%
x = -122.5
y = 52.5
df2 <- data.frame()
for (year in 2001:2022){
    for (season in 1:12){
        subgrid <- subsetGrid(grid = ba.mergeGrid5, year = year, season = season, lonLim  = x, latLim  = y)
        df2 <- rbind(df2, c(year, season, subgrid$Data))
    }        
}
colnames(df2) = c('Year', 'Month','Burned_area')
df2$Year <- as.character(df2$Year)
for (row in 1:nrow(df2)){
    if (df2$Burned_area[row] != 0){
        df2$Burned_area[row] = df2$Month[row]
    }
}

startFireSeasson = df.fireSeasson[df.fireSeasson$coord_x == x & df.fireSeasson$coord_y == y, ]$main_fire_season_start
endFireSeasson = df.fireSeasson[df.fireSeasson$coord_x == x & df.fireSeasson$coord_y == y, ]$main_fire_season_end
ggplot(df2, aes(x = Burned_area, y = Year, fill = stat(x))) +
  geom_density_ridges_gradient(scale = 2, rel_min_height = 0.01, gradient_lwd = 1.)+
  scale_fill_viridis_c(name = "Meses Fire Seasson", option = "C") +
  labs(
    title = 'Fire Seasson años 2001-2022 en un pixel',
    subtitle = paste0('Coordenadas ','lon = ',x,' lat = ',y)
  ) +
  theme_ridges(font_size = 13, grid = TRUE) + 
  theme(axis.title.y = element_blank()) +
  geom_vline(xintercept = c(startFireSeasson, endFireSeasson), color = "red", linetype = "dashed") +
  geom_vline(xintercept = 7, color = "blue", linetype = "dashed")
ggsave(paste0('FireSeasson',x,'_',y,'.png'))
df.fireSeasson[df.fireSeasson$coord_x == x & df.fireSeasson$coord_y == y, ]
# Out:
# Picking joint bandwidth of 2.3
#
# Saving 6.67 x 6.67 in image
#
# Picking joint bandwidth of 2.3
#     coord_x coord_y FireSeassonOrNot main_fire_season_start
# 425 -122.5  52.5    1                1
#     main_fire_season_end secondary_fire_season_start secondary_fire_season_end
# 425 1                    3                           7
#     fireSeassonLength SeassonalConcentration SeassonalTiming FBA
# 425 6                 0.872338               1.104374        0.9706786
# plot without title

# %%
ggplot(df2, aes(x = Burned_area, y = Year, fill = stat(x))) +
  geom_density_ridges_gradient(scale = 2, rel_min_height = 0.01, gradient_lwd = 1.) +
  scale_x_continuous(expand = c(0, 0)) +
  scale_y_discrete(expand = expansion(mult = c(0.01, 0.01)))+
  scale_fill_viridis_c(name = "Área quemada", option = "C") +
  labs(
    title = 'Área quemada años 2001-2022 en un pixel',
    subtitle = 'Coordenadas lon = -157.5 lat = 17.5'
  ) +
  theme_ridges(font_size = 13, grid = TRUE) + 
  theme(axis.title.y = element_blank())
# Out:
# Picking joint bandwidth of 2.3
# plot without title

# %% [markdown]
# ********************************************************************************************************************

# %%
library('visualizeR')
library('transformeR')

# %%
quantity2clim <- function(quantity, what, ref.grid, backperm = NULL) {
  if(!is.null(backperm)){quantity <- quantity[backperm]}
  mat <- matrix(quantity, nrow = 1)  
  ref.grid$Data <- mat2Dto3Darray(mat, x = ref.grid$xyCoords$x , y = ref.grid$xyCoords$y)
  attr(ref.grid$Data, "climatology:fun") <- what
  return(ref.grid)
}

# %%
load('../3.Datos generados/dataframes/df.series_grid_25.Rdata',verbose = TRUE)
load('../1.Upscaling/upscaling_ba/ba_grid_25.Rdata',verbose = TRUE)
load('../1.Upscaling/upscaling_fba/ fba_grid_25.Rdata',verbose = TRUE)
# Out:
# Loading objects:
#   df.seriesTemporales_conCoords
# Loading objects:
#   ba.mergeGrid25
# Loading objects:
#   fba_25

# %%
df_sinCeros <- data.frame()
for (i in 1:nrow(df.seriesTemporales_conCoords)){
    if (all(unlist(df.seriesTemporales_conCoords[i,3:14]) != 0)){
        df_sinCeros <- rbind(df_sinCeros, df.seriesTemporales_conCoords[i,])
    }
}

# %%
item = 1
x = df_sinCeros[item,]$coord_x
y = df_sinCeros[item,]$coord_y
area_quemada = unlist(df_sinCeros[item,3:14])
meses = seq(1,12)
plot(meses,area_quemada, type = 'b', xlab = 'Meses',ylab = "Área quemada")
grid()
# Out:
# plot without title

# %% [markdown]
# Vamos a incluir también sus desviaciones

# %%
func.mediasMensuales <- function(grid, x, y, func = mean){
        results <- c()
        for (season in 1:12){
            new_grid <- subsetGrid(grid = grid,season = season, lonLim  = x, latLim  = y)
            var_name <- paste("season", season, sep = "_")
            assign(var_name,new_grid)
            results <- c(results, func(get(var_name)$Data))
        }
        return(results)
}
minimo = func.mediasMensuales(grid = ba.mergeGrid25, x = x, y = y, func = min)
maximo = func.mediasMensuales(grid = ba.mergeGrid25, x = x, y = y, func = max)
medias = func.mediasMensuales(grid = ba.mergeGrid25, x = x, y = y, func = mean) 
desviacion = func.mediasMensuales(grid = ba.mergeGrid25, x = x, y = y, func = sd)

# %%
area_quemada = unlist(df_sinCeros[item,3:14])
arriba = area_quemada + desviacion
meses = seq(1,12)
plot(meses,area_quemada, type = 'b', xlab = 'Meses',ylab = "Área quemada", ylim = range(c(minimo, arriba)))
points(meses, arriba, col = 'orange') 
lines(meses, arriba, lty = 2, col = 'orange')  # Línea arriba de la media
points(meses, maximo,lty = 2, col = 'red' )
lines(meses, maximo,lty = 2, col = 'red' )
grid()
# Out:
# plot without title

# %%
spatialPlot(climatology(fba_5), backdrop.theme = 'coastline')
# Out:
# [2023-09-10 19:40:56] - Computing climatology...
#
# [2023-09-10 19:40:56] - Done.
# plot without title

# %% [markdown]
# Vamos a probar a hacer un estudio de las densidades de una serie de datos cualquier a nivel burdo

# %%
#ruta <- '../0.Data/MODIS_OLCI_ba_200101-202205.Rdata'
ruta <- '../1.Upscaling/upscaling_ba/ba_grid_05.Rdata'
grid_ <- get(load(ruta))

# %%
x = -118.875
y = 48.125
df2 <- data.frame()
for (year in 2001:2022){
    for (season in 1:12){
        subgrid <- subsetGrid(grid = grid_, year = year, season = season, lonLim  = x, latLim  = y)
        df2 <- rbind(df2, c(year, season, subgrid$Data))
    }        
}
colnames(df2) = c('Year', 'Month','Burned_area')

# %%
df <- df2
df$Burned_area<- ifelse(df$Burned_area != 0, 1, 0)

# %%
for (year in 2001:2022){
    nombre_variable <- paste0('year_',year)
    vector <- as.vector(df2[df2$Year == year, ]$Burned_area)
    assign(nombre_variable, (vector))
}

# %%
df_years <- data.frame(year_2001,year_2002,year_2003, year_2004,
           year_2005,year_2006,year_2007,year_2008,
           year_2009,year_2010,year_2011,year_2012,
           year_2013,year_2014,year_2015,year_2016,
           year_2017,year_2018,year_2019,year_2020,
           year_2021)
frecuencia_incendios <- c()
for (row in 1:nrow(df_years)){
    frecuencia_incendios <- c(frecuencia_incendios, sum(df_years[row,]))
}
df_years$frecuencia_incendios <- frecuencia_incendios

# %%
x = -118.875
y = 48.125
for (year in c(2001:2022)){
    serieGrid = subsetGrid(grid = grid_,  year = year, lonLim = x, latLim = y)
    nombre_variable <- paste0('year_',year)
    assign(nombre_variable, serieGrid$Data)
    #densidad <- density(serieGrid$Data)
    #assign(nombre_variable, densidad)
}

# %%
for (year in 2001:2022){
    nombre_variable <- paste0('year_',year)
    vector <- as.vector(df2[df2$Year == year, ]$Burned_area)
    assign(nombre_variable, (vector))
}
